# %% [markdown]
# # 2o Examen parcial
#
# ### TSMC-I: Análisis de datos en Python
#
# Martes 23 de enero de 2024

# %% [markdown]
# Nombre:
#
#
# Unidad:

# %% [markdown]
# **1. Cargue los datos de 30,000 llamadas al 911 (*llamadas_2023.csv* en Github) y realice lo siguiente:**
#
# **a)** Obtenga un Dataframe con las categorias de incidentes reportados en las llamadas y su frecuencia, donde la frecuencia supere 100. Obtenga un gráfico que ilustre esto.
#
# **b)** Obtenga un Dataframe con los tipos de incidentes reportados en las llamadas y su frecuencia, donde la frecuencia supere 300. Obtenga un gráfico que ilustre esto.
#
# **c)** Obtenga un gráfico de barras que iluste el número de llamadas por alcaldía.
#
# **d)** ¿Cuál fué el día donde se reportaron más llamadas?
#
# **e)** ¿Cuales son las 5 colonias donde se registraron más llamadas?

# %% [markdown]
# **2. Extraiga las tabla de "Terremotos de mayor magnitud" del siguiente enlace:**
#
# https://es.wikipedia.org/wiki/Anexo:Terremotos_de_mayor_magnitud
#
# y realice lo siguiente:
#
# **a)** Obtenga el siguiente Dataframe.
#
# Nota. Si alguna fila no contiene la hora, coloquela como 00:00.
# Si alguna fila no contiene una magnitud en particular, coloque alguna del rango proporcionado.

# %% [markdown]
# ![df1.png](attachment:df1.png)

# %% [markdown]
# **b)** Indexe el dataframe anterior por año en orden acendente y obtenga el siguiente gráfico de barras:

# %% [markdown]
# ![barras.png](attachment:barras.png)

# %% [markdown]
# **c)** Del dataframe anterior, obtenga un Dataframe que contenga todos los terremotos con magnitud mayor o igual a 8.8 y obtenga un gráfico de barras que ilustre esto.

# %% [markdown]
# **d)** Agrupe las magnitudes de terremotos en niveles como sigue:
#
#     nivel 1: [8.4,8.6]
#
#     nivel 2: [8.7,8.9]
#
#     nivel 3: [9.0,9.2]
#
#     nivel 4: [9.3,9.5]
#
# Posteriormente agregue una columna al dataframe que indique el nivel.

# %% [markdown]
# **e)** Del dataframe obtenido en el inciso anterior, indexe sobre la fecha para obtener el siguiente dataframe.

# %% [markdown]
# ![df4.png](attachment:df4.png)
